# %% [markdown]
# # Importing Depedency packages for Data Analysis and Visualization

# %%
import os as o
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
files = o.listdir('sales_data')

# %%
files
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %% [markdown]
# # Consolidating all files

# %%
df = pd.DataFrame()

for file in files:
    f_r = pd.read_csv("./sales_data/" + file)  
    df = pd.concat([f_r,df])
 
con_file = df
con_file.to_csv('concate_file.csv',index = False)

# %%
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001
# ...

# %% [markdown]
# # SOURCE FILE BACK UP

# %%
df_cpy = df

# %%
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001
# ...

# %%
df_cpy
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %% [markdown]
# # CLEAN UP DATA

# %%
df.dropna(inplace = True)

# %%
df.count()
# Out:
# Order ID            186305
# Product             186305
# Quantity Ordered    186305
# Price Each          186305
# Order Date          186305
# Purchase Address    186305
# dtype: int64

# %%
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001
# ...

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
df.head(2)
# Out:
#   Order ID                Product Quantity Ordered Price Each      Order Date  \
# 0   248151  AA Batteries (4-pack)                4       3.84  09/17/19 14:44
# 1   248152   USB-C Charging Cable                2      11.95  09/29/19 10:19
#
#                       Purchase Address
# 0  380 North St, Los Angeles, CA 90001
# 1         511 8th St, Austin, TX 73301

# %%
df['Month'] = df['Order Date'].str[0:2]

# %%
df['Month'].head()
# Out:
# 0    09
# 1    09
# 2    09
# 3    09
# 4    09
# Name: Month, dtype: object

# %%
df['Month'].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-745f6d591a5b> in <module>
# ----> 1 df['Month'].astype('int32')
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5541         else:
#    5542             # else, only a single dtype is given
# -> 5543             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5544             return self._constructor(new_data).__finalize__(self, method="astype")
#    5545
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
# ...

# %%
df_or = df[df['Month'] == 'Or']

# %%
df_or.count()
# Out:
# Order ID            355
# Product             355
# Quantity Ordered    355
# Price Each          355
# Order Date          355
# Purchase Address    355
# Month               355
# dtype: int64

# %%
df_or.head(355)
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 1679   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3732   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3790   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 4323   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 5579   Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...         ...      ...               ...         ...         ...
# 15280  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17208  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17324  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17339  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17744  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address Month
# 1679   Purchase Address    Or
# 3732   Purchase Address    Or
# 3790   Purchase Address    Or
# 4323   Purchase Address    Or
# ...

# %%
df = df[df['Month'] != 'Or']

# %%
df.count()
# Out:
# Order ID            185950
# Product             185950
# Quantity Ordered    185950
# Price Each          185950
# Order Date          185950
# Purchase Address    185950
# Month               185950
# dtype: int64

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month               object
# dtype: object

# %%
df['Month'] = df ['Month'].astype('int32')
# Out:
# <ipython-input-56-08c836db2860>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'] = df ['Month'].astype('int32')

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month                int32
# dtype: object

# %%
data = pd.read_csv('concate_file.csv')

# %%
data
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        248151     AA Batteries (4-pack)                4       3.84
# 1        248152      USB-C Charging Cable                2      11.95
# 2        248153      USB-C Charging Cable                1      11.95
# 3        248154          27in FHD Monitor                1     149.99
# 4        248155      USB-C Charging Cable                1      11.95
# ...         ...                       ...              ...        ...
# 186845   194090              Google Phone                1        600
# 186846   194091     AA Batteries (4-pack)                1       3.84
# 186847   194092    AAA Batteries (4-pack)                2       2.99
# 186848   194093     AA Batteries (4-pack)                1       3.84
# 186849   194094  Lightning Charging Cable                1      14.95
#
#             Order Date                        Purchase Address
# 0       09/17/19 14:44     380 North St, Los Angeles, CA 90001
# ...

# %%
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address  Month
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001      9
# ...

# %%
df['Month'].unique()
# Out:
# array([ 9, 10, 11, 12,  5,  6,  3,  4,  7,  8,  1,  2])

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month                int32
# dtype: object

# %%
df['Year'] = df['Order Date'].str[6:8]
# Out:
# <ipython-input-64-bc93fff832dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Order Date'].str[6:8]

# %%
df['Year']
# Out:
# 0        19
# 1        19
# 2        19
# 3        19
# 4        19
#          ..
# 18378    19
# 18379    19
# 18380    19
# 18381    19
# 18382    19
# Name: Year, Length: 185950, dtype: object

# %%
df['Year'].unique()
# Out:
# array(['19', '20'], dtype=object)

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month                int32
# Year                object
# dtype: object

# %%
df['Price Each'] = df['Price Each'].astype('float64')
# Out:
# <ipython-input-68-894c902b0469>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price Each'] = df['Price Each'].astype('float64')

# %%
o.getcwd()
# Out:
# 'C:\\Users\\Rajesh'

# %%
df.head()
# Out:
#   Order ID                Product Quantity Ordered  Price Each  \
# 0   248151  AA Batteries (4-pack)                4        3.84
# 1   248152   USB-C Charging Cable                2       11.95
# 2   248153   USB-C Charging Cable                1       11.95
# 3   248154       27in FHD Monitor                1      149.99
# 4   248155   USB-C Charging Cable                1       11.95
#
#        Order Date                       Purchase Address  Month Year
# 0  09/17/19 14:44    380 North St, Los Angeles, CA 90001      9   19
# 1  09/29/19 10:19           511 8th St, Austin, TX 73301      9   19
# 2  09/16/19 17:48  151 Johnson St, Los Angeles, CA 90001      9   19
# 3  09/27/19 07:52      355 Hickory St, Seattle, WA 98101      9   19
# 4  09/01/19 19:03          125 5th St, Atlanta, GA 30301      9   19

# %%
def door(add):
    return add.split(",")[1].strip(" ")
def state(add):
    return add.split(",")[2].split(" ")[1]

df['City'] = df['Purchase Address'].apply(lambda x : f"{door(x)} ({state(x)})")
df.head()
# Out:
# <ipython-input-71-de0e9edc0ccc>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['City'] = df['Purchase Address'].apply(lambda x : f"{door(x)} ({state(x)})")
#   Order ID                Product Quantity Ordered  Price Each  \
# 0   248151  AA Batteries (4-pack)                4        3.84
# 1   248152   USB-C Charging Cable                2       11.95
# 2   248153   USB-C Charging Cable                1       11.95
# 3   248154       27in FHD Monitor                1      149.99
# 4   248155   USB-C Charging Cable                1       11.95
#
#        Order Date                       Purchase Address  Month Year  \
# 0  09/17/19 14:44    380 North St, Los Angeles, CA 90001      9   19
# ...

# %% [markdown]
# ### WRK_FILE BACKUP

# %%
df_wrk =df

# %% [markdown]
# ### 1.Which Month has high Worth for sales

# %%
df['Sales'] = df['Quantity Ordered'].astype('int32') * df['Price Each'].astype('float')
# Out:
# <ipython-input-73-ccab5b4b02ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sales'] = df['Quantity Ordered'].astype('int32') * df['Price Each'].astype('float')

# %%
sales_cri = df['Sales'].groupby(df['Month'])
print(sales_cri())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-5808a8c3a56a> in <module>
#       1 sales_cri = df['Sales'].groupby(df['Month'])
# ----> 2 print(sales_cri())
#
# TypeError: 'SeriesGroupBy' object is not callable

# %%
df.head()
# Out:
#   Order ID                Product Quantity Ordered  Price Each  \
# 0   248151  AA Batteries (4-pack)                4        3.84
# 1   248152   USB-C Charging Cable                2       11.95
# 2   248153   USB-C Charging Cable                1       11.95
# 3   248154       27in FHD Monitor                1      149.99
# 4   248155   USB-C Charging Cable                1       11.95
#
#        Order Date                       Purchase Address  Month Year  \
# 0  09/17/19 14:44    380 North St, Los Angeles, CA 90001      9   19
# 1  09/29/19 10:19           511 8th St, Austin, TX 73301      9   19
# 2  09/16/19 17:48  151 Johnson St, Los Angeles, CA 90001      9   19
# 3  09/27/19 07:52      355 Hickory St, Seattle, WA 98101      9   19
# 4  09/01/19 19:03          125 5th St, Atlanta, GA 30301      9   19
#
#                City   Sales
# 0  Los Angeles (CA)   15.36
# 1       Austin (TX)   23.90
# 2  Los Angeles (CA)   11.95
# 3      Seattle (WA)  149.99
# ...

# %%
df['Sales'].groupby(df['Month']).describe()
# Out:
#          count        mean         std   min    25%    50%    75%      max
# Month
# 1       9709.0  187.687376  330.987224  2.99  11.95  14.95  150.0  1999.98
# 2      11975.0  183.884962  325.836501  2.99  11.95  14.95  150.0  1700.00
# 3      15153.0  185.250471  331.331329  2.99  11.95  14.95  150.0  1700.00
# 4      18279.0  185.495390  331.985219  2.99  11.95  14.95  150.0  3400.00
# 5      16566.0  190.305852  343.054180  2.99  11.95  14.95  150.0  3400.00
# 6      13554.0  190.187565  337.420812  2.99  11.95  14.95  150.0  3400.00
# 7      14293.0  185.249826  332.873967  2.99  11.95  14.95  150.0  1700.00
# 8      11961.0  187.648849  332.290186  2.99  11.95  14.95  150.0  1700.00
# 9      11621.0  180.497387  328.570216  2.99  11.95  14.95  150.0  1700.00
# 10     20282.0  184.238580  334.148820  2.99  11.95  14.95  150.0  1999.98
# 11     17573.0  182.074956  330.108334  2.99  11.95  14.95  150.0  1700.00
# ...

# %% [markdown]
# ## Soln: December month is considered Peak Month of the Year for Sales

# %%
sns.relplot(x =df['Month'], y = df['Sales'])

# %% [markdown]
# # Above Visualisation explains about Sales for every Month

# %%
df.shape
# Out:
# (185950, 10)

# %%
display(df.shape)
# Out:
# (185950, 10)

# %% [markdown]
# ### Q2: What City sold most Product
